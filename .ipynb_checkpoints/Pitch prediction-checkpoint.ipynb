# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\marci\DataScience\Pitch_predictions\pitch-aileron\train.csv')
print(df.head())
print(df.shape)
# Out:
#    CbRt  SGZ     P     Q  CrRl  AbRl  DfClb  DfRlRt  DfDfClb     ST1     ST2  \
# 0  -437   10 -0.34  0.15  -0.4   -20      4  -0.017     -0.4 -0.0013 -0.0016
# 1  -282  -34 -0.40  0.00   0.3   -10     -5  -0.020      1.6 -0.0010 -0.0010
# 2   -90  -20 -0.21 -0.02   0.2    -8      3  -0.004     -0.2 -0.0005 -0.0006
# 3  -164    0  0.19  0.08   2.0   -11    -12  -0.009      0.5 -0.0009 -0.0008
# 4     8  -36  0.41  0.09   1.8   -19      9  -0.022     -0.1 -0.0021 -0.0022
#
#       ST3     ST4   DfST1  DfST2   DfST3  DfST4      Sa  Target
# 0 -0.0016 -0.0016  0.0003      0  0.0000      0 -0.0016   0.022
# 1 -0.0010 -0.0010  0.0000      0  0.0000      0 -0.0010   0.016
# 2 -0.0006 -0.0006  0.0000      0  0.0000      0 -0.0006   0.019
# 3 -0.0008 -0.0008 -0.0002      0 -0.0001      0 -0.0008   0.017
# 4 -0.0022 -0.0024  0.0001      0  0.0001      0 -0.0024   0.036
# (4000, 19)

# %%
# checking for null_values
df.isnull().sum()
# Out:
# CbRt       0
# SGZ        0
# P          0
# Q          0
# CrRl       0
# AbRl       0
# DfClb      0
# DfRlRt     0
# DfDfClb    0
# ST1        0
# ST2        0
# ST3        0
# ST4        0
# DfST1      0
# DfST2      0
# DfST3      0
# DfST4      0
# Sa         0
# Target     0
# dtype: int64

# %%
# df=df.loc[:, df.columns!='Target']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df_scaled = pd.DataFrame(ss.fit_transform(df),columns = df.columns)

# %%
print(df_scaled)
# Out:
#           CbRt       SGZ         P         Q      CrRl      AbRl     DfClb  \
# 0    -1.556246  0.888607 -1.038445  0.834413 -0.453480 -2.282414  0.422469
# 1    -0.990526 -0.839837 -1.231305 -0.473615  0.271384  0.187263 -0.421531
# 2    -0.289763 -0.289878 -0.620582 -0.648019  0.167832  0.681199  0.328691
# 3    -0.559849  0.495779  0.665149  0.224000  2.031767 -0.059704 -1.077975
# 4     0.067918 -0.918403  1.372302  0.311202  1.824663 -2.035446  0.891357
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  2.038814  1.085021  1.500875  2.229644 -2.835175 -1.047575  0.141135
# 3996 -0.943078 -0.604140 -0.395579 -0.996827 -0.349928  1.175134  0.985135
# 3997  0.286907  2.184940  0.536576 -0.212010  1.617559  1.669070 -0.327753
# 3998  0.925623  1.045738  2.593747  2.055240 -1.385447 -1.294543 -2.297086
# 3999 -0.552549 -0.014898 -0.170576 -0.735221  0.374936  0.434231  0.610024
#
# ...

# %%
print(df)
# Out:
#       CbRt  SGZ     P     Q  CrRl  AbRl  DfClb  DfRlRt  DfDfClb     ST1  \
# 0     -437   10 -0.34  0.15  -0.4   -20      4  -0.017     -0.4 -0.0013
# 1     -282  -34 -0.40  0.00   0.3   -10     -5  -0.020      1.6 -0.0010
# 2      -90  -20 -0.21 -0.02   0.2    -8      3  -0.004     -0.2 -0.0005
# 3     -164    0  0.19  0.08   2.0   -11    -12  -0.009      0.5 -0.0009
# 4        8  -36  0.41  0.09   1.8   -19      9  -0.022     -0.1 -0.0021
# ...    ...  ...   ...   ...   ...   ...    ...     ...      ...     ...
# 3995   548   15  0.45  0.31  -2.7   -15      1   0.029     -6.6 -0.0003
# 3996  -269  -28 -0.14 -0.06  -0.3    -6     10  -0.011     -1.1 -0.0005
# 3997    68   43  0.15  0.03   1.6    -4     -4  -0.009      0.2 -0.0004
# 3998   243   14  0.79  0.29  -1.3   -16    -25   0.013     -0.2 -0.0008
# 3999  -162  -13 -0.07 -0.03   0.4    -9      6  -0.002     -0.2 -0.0005
#
#          ST2     ST3     ST4   DfST1  DfST2   DfST3  DfST4      Sa  Target
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CbRt     4000 non-null   int64
#  1   SGZ      4000 non-null   int64
#  2   P        4000 non-null   float64
#  3   Q        4000 non-null   float64
#  4   CrRl     4000 non-null   float64
#  5   AbRl     4000 non-null   int64
#  6   DfClb    4000 non-null   int64
#  7   DfRlRt   4000 non-null   float64
#  8   DfDfClb  4000 non-null   float64
#  9   ST1      4000 non-null   float64
#  10  ST2      4000 non-null   float64
#  11  ST3      4000 non-null   float64
#  12  ST4      4000 non-null   float64
#  13  DfST1    4000 non-null   float64
#  14  DfST2    4000 non-null   int64
#  15  DfST3    4000 non-null   float64
#  16  DfST4    4000 non-null   int64
#  17  Sa       4000 non-null   float64
#  18  Target   4000 non-null   float64
# dtypes: float64(13), int64(6)
# memory usage: 593.9 KB

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.plot(kind="scatter", x="DfST1", y="DfST2")
df.plot(kind="scatter", x="DfST3", y="DfST4")
# Out:
# <AxesSubplot:xlabel='DfST3', ylabel='DfST4'>

# %%
corr_matrix = df.corr()

corr_matrix['Target'].sort_values(ascending=False)
# Out:
# Target     1.000000
# Q          0.298212
# CbRt       0.129779
# P          0.063978
# DfRlRt     0.043110
# SGZ       -0.005597
# DfST1     -0.029396
# DfST3     -0.029961
# CrRl      -0.066370
# DfDfClb   -0.072699
# DfClb     -0.102077
# AbRl      -0.350141
# ST4       -0.598118
# Sa        -0.598118
# ST2       -0.605231
# ST3       -0.605231
# ST1       -0.620095
# DfST2           NaN
# DfST4           NaN
# Name: Target, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["Target", "ST1", "ST3",
"ST2"]
scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='Target', ylabel='Target'>,
#         <AxesSubplot:xlabel='ST1', ylabel='Target'>,
#         <AxesSubplot:xlabel='ST3', ylabel='Target'>,
#         <AxesSubplot:xlabel='ST2', ylabel='Target'>],
#        [<AxesSubplot:xlabel='Target', ylabel='ST1'>,
#         <AxesSubplot:xlabel='ST1', ylabel='ST1'>,
#         <AxesSubplot:xlabel='ST3', ylabel='ST1'>,
#         <AxesSubplot:xlabel='ST2', ylabel='ST1'>],
#        [<AxesSubplot:xlabel='Target', ylabel='ST3'>,
#         <AxesSubplot:xlabel='ST1', ylabel='ST3'>,
#         <AxesSubplot:xlabel='ST3', ylabel='ST3'>,
#         <AxesSubplot:xlabel='ST2', ylabel='ST3'>],
#        [<AxesSubplot:xlabel='Target', ylabel='ST2'>,
#         <AxesSubplot:xlabel='ST1', ylabel='ST2'>,
#         <AxesSubplot:xlabel='ST3', ylabel='ST2'>,
#         <AxesSubplot:xlabel='ST2', ylabel='ST2'>]], dtype=object)

# %%
df.plot(kind="scatter", x="ST1", y="Target", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='ST1', ylabel='Target'>
