# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\marci\DataScience\Pitch_predictions\pitch-aileron\train.csv')
print(df.head())
print(df.shape)
# Out:
#    CbRt  SGZ     P     Q  CrRl  AbRl  DfClb  DfRlRt  DfDfClb     ST1     ST2  \
# 0  -437   10 -0.34  0.15  -0.4   -20      4  -0.017     -0.4 -0.0013 -0.0016
# 1  -282  -34 -0.40  0.00   0.3   -10     -5  -0.020      1.6 -0.0010 -0.0010
# 2   -90  -20 -0.21 -0.02   0.2    -8      3  -0.004     -0.2 -0.0005 -0.0006
# 3  -164    0  0.19  0.08   2.0   -11    -12  -0.009      0.5 -0.0009 -0.0008
# 4     8  -36  0.41  0.09   1.8   -19      9  -0.022     -0.1 -0.0021 -0.0022
#
#       ST3     ST4   DfST1  DfST2   DfST3  DfST4      Sa  Target
# 0 -0.0016 -0.0016  0.0003      0  0.0000      0 -0.0016   0.022
# 1 -0.0010 -0.0010  0.0000      0  0.0000      0 -0.0010   0.016
# 2 -0.0006 -0.0006  0.0000      0  0.0000      0 -0.0006   0.019
# 3 -0.0008 -0.0008 -0.0002      0 -0.0001      0 -0.0008   0.017
# 4 -0.0022 -0.0024  0.0001      0  0.0001      0 -0.0024   0.036
# (4000, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CbRt     4000 non-null   int64
#  1   SGZ      4000 non-null   int64
#  2   P        4000 non-null   float64
#  3   Q        4000 non-null   float64
#  4   CrRl     4000 non-null   float64
#  5   AbRl     4000 non-null   int64
#  6   DfClb    4000 non-null   int64
#  7   DfRlRt   4000 non-null   float64
#  8   DfDfClb  4000 non-null   float64
#  9   ST1      4000 non-null   float64
#  10  ST2      4000 non-null   float64
#  11  ST3      4000 non-null   float64
#  12  ST4      4000 non-null   float64
#  13  DfST1    4000 non-null   float64
#  14  DfST2    4000 non-null   int64
#  15  DfST3    4000 non-null   float64
#  16  DfST4    4000 non-null   int64
#  17  Sa       4000 non-null   float64
#  18  Target   4000 non-null   float64
# dtypes: float64(13), int64(6)
# memory usage: 593.9 KB

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
corr_matrix = df.corr()

corr_matrix['Target'].sort_values(ascending=False)
# Out:
# Target     1.000000
# Q          0.298212
# CbRt       0.129779
# P          0.063978
# DfRlRt     0.043110
# SGZ       -0.005597
# DfST1     -0.029396
# DfST3     -0.029961
# CrRl      -0.066370
# DfDfClb   -0.072699
# DfClb     -0.102077
# AbRl      -0.350141
# ST4       -0.598118
# Sa        -0.598118
# ST2       -0.605231
# ST3       -0.605231
# ST1       -0.620095
# DfST2           NaN
# DfST4           NaN
# Name: Target, dtype: float64

# %%
df_T= df.drop('Target', axis=1)

# %%
df_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CbRt     4000 non-null   int64
#  1   SGZ      4000 non-null   int64
#  2   P        4000 non-null   float64
#  3   Q        4000 non-null   float64
#  4   CrRl     4000 non-null   float64
#  5   AbRl     4000 non-null   int64
#  6   DfClb    4000 non-null   int64
#  7   DfRlRt   4000 non-null   float64
#  8   DfDfClb  4000 non-null   float64
#  9   ST1      4000 non-null   float64
#  10  ST2      4000 non-null   float64
#  11  ST3      4000 non-null   float64
#  12  ST4      4000 non-null   float64
#  13  DfST1    4000 non-null   float64
#  14  DfST2    4000 non-null   int64
#  15  DfST3    4000 non-null   float64
#  16  DfST4    4000 non-null   int64
#  17  Sa       4000 non-null   float64
# dtypes: float64(12), int64(6)
# memory usage: 562.6 KB

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df_scaled = pd.DataFrame(ss.fit_transform(df_T),columns = df_T.columns)

# %%
df_scaled
# Out:
#           CbRt       SGZ         P         Q      CrRl      AbRl     DfClb  \
# 0    -1.556246  0.888607 -1.038445  0.834413 -0.453480 -2.282414  0.422469
# 1    -0.990526 -0.839837 -1.231305 -0.473615  0.271384  0.187263 -0.421531
# 2    -0.289763 -0.289878 -0.620582 -0.648019  0.167832  0.681199  0.328691
# 3    -0.559849  0.495779  0.665149  0.224000  2.031767 -0.059704 -1.077975
# 4     0.067918 -0.918403  1.372302  0.311202  1.824663 -2.035446  0.891357
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  2.038814  1.085021  1.500875  2.229644 -2.835175 -1.047575  0.141135
# 3996 -0.943078 -0.604140 -0.395579 -0.996827 -0.349928  1.175134  0.985135
# 3997  0.286907  2.184940  0.536576 -0.212010  1.617559  1.669070 -0.327753
# 3998  0.925623  1.045738  2.593747  2.055240 -1.385447 -1.294543 -2.297086
# 3999 -0.552549 -0.014898 -0.170576 -0.735221  0.374936  0.434231  0.610024
#
#         DfRlRt   DfDfClb       ST1       ST2       ST3       ST4     DfST1  \
# 0    -1.260691 -0.376021 -1.409247 -2.122261 -2.122261 -2.096492  3.629565
# 1    -1.496828  1.768686 -0.647938 -0.625691 -0.625691 -0.613344  0.103719
# 2    -0.237435 -0.161550  0.620911  0.372022  0.372022  0.375422  0.103719
# 3    -0.630995  0.589097 -0.394168 -0.126834 -0.126834 -0.118961 -2.246846
# 4    -1.654252 -0.054315 -3.439406 -3.618831 -3.618831 -4.074024  1.279001
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  2.360063 -7.024610  1.128451  1.120307  1.120307  1.116996  0.103719
# 3996 -0.788419 -1.126668  0.620911  0.621451  0.621451  0.375422  0.103719
# 3997 -0.630995  0.267391  0.874681  0.870879  0.870879  0.869805  0.103719
# 3998  1.100670 -0.161550 -0.140398  0.372022  0.372022  0.375422 -2.246846
# 3999 -0.080011 -0.161550  0.620911  0.621451  0.621451  0.622613  0.103719
#
#       DfST2     DfST3  DfST4        Sa
# 0       0.0  0.054091    0.0 -2.096492
# 1       0.0  0.054091    0.0 -0.613344
# 2       0.0  0.054091    0.0  0.375422
# 3       0.0 -1.676818    0.0 -0.118961
# 4       0.0  1.784999    0.0 -4.074024
# ...     ...       ...    ...       ...
# 3995    0.0  0.054091    0.0  1.116996
# 3996    0.0  0.054091    0.0  0.375422
# 3997    0.0  0.054091    0.0  0.869805
# 3998    0.0  0.054091    0.0  0.375422
# 3999    0.0  0.054091    0.0  0.622613
#
# [4000 rows x 18 columns]

# %%
df_labels = df['Target'].copy()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df_scaled, df_labels)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
df_pred=lin_reg.predict(df_scaled)
lin_mse = mean_squared_error(df_labels, df_pred)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 0.0028313759881638326

# %%
lin_reg
# Out:
# LinearRegression()

# %%
df_test=pd.read_csv(r'C:\Users\marci\DataScience\Pitch_predictions\pitch-aileron\test.csv')

# %%
df_test_no_Id = df_test.loc[:, df_test.columns!='Id']

df_test_no_Id
# Out:
#      CbRt  SGZ     P     Q  CrRl  AbRl  DfClb  DfRlRt  DfDfClb     ST1  \
# 0    -176  -42  0.09  0.03  -0.3   -18     13   0.023      0.0 -0.0007
# 1    -363   29  0.10  0.16   1.5   -11    -14  -0.004      0.0 -0.0007
# 2    -181  -28 -0.20  0.07  -0.7    -9     -6  -0.005      0.3 -0.0009
# 3    -241    9  0.31  0.09  -0.4   -14     -1   0.012      0.1 -0.0008
# 4       5  -26 -0.22  0.01   0.4    -8      3  -0.010     -0.6 -0.0005
# ..    ...  ...   ...   ...   ...   ...    ...     ...      ...     ...
# 995  -108  -20 -0.29  0.18  -0.3   -16     -6   0.005     -0.2 -0.0012
# 996  -181  -24  0.32 -0.01   0.0    -7     -4  -0.004      0.2 -0.0005
# 997    71  -24 -0.38 -0.04   0.3    -6      5  -0.004      0.0 -0.0004
# 998  -573    0  0.24  0.13   0.4   -13    -10  -0.004      0.1 -0.0008
# 999    87  -39  0.44  0.06  -0.3   -13      2  -0.007     -0.8 -0.0008
#
#         ST2     ST3     ST4   DfST1  DfST2   DfST3  DfST4      Sa
# 0   -0.0007 -0.0007 -0.0007  0.0000      0  0.0000      0 -0.0007
# 1   -0.0007 -0.0007 -0.0007  0.0000      0  0.0000      0 -0.0007
# 2   -0.0012 -0.0012 -0.0012  0.0003      0  0.0000      0 -0.0012
# 3   -0.0007 -0.0007 -0.0007 -0.0002      0  0.0000      0 -0.0007
# 4   -0.0006 -0.0006 -0.0007  0.0001      0  0.0001      0 -0.0007
# ..      ...     ...     ...     ...    ...     ...    ...     ...
# 995 -0.0012 -0.0012 -0.0012  0.0000      0  0.0000      0 -0.0012
# 996 -0.0005 -0.0005 -0.0005  0.0000      0 -0.0001      0 -0.0005
# 997 -0.0004 -0.0004 -0.0005  0.0000      0  0.0000      0 -0.0005
# 998 -0.0008 -0.0008 -0.0008  0.0000      0  0.0000      0 -0.0008
# 999 -0.0008 -0.0008 -0.0008  0.0000      0  0.0000      0 -0.0008
#
# [1000 rows x 18 columns]

# %%
df_test_scaled = pd.DataFrame(ss.fit_transform(df_test_no_Id),columns = df_test_no_Id.columns)

df_test_scaled
# Out:
#          CbRt       SGZ         P         Q      CrRl      AbRl     DfClb  \
# 0   -0.538788 -1.077015  0.354986 -0.214847 -0.442399 -1.704931  1.298515
# 1   -1.217522  1.687457  0.387343  0.888239  1.433054 -0.028028 -1.259855
# 2   -0.556936 -0.531908 -0.583361  0.124564 -0.859166  0.451087 -0.501819
# 3   -0.774711  0.908732  1.066836  0.294269 -0.546590 -0.746701 -0.028047
# 4    0.118169 -0.454035 -0.648074 -0.384553  0.286944  0.690644  0.350970
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.291975 -0.220418 -0.874572  1.057945 -0.442399 -1.225816 -0.501819
# 996 -0.556936 -0.376163  1.099193 -0.554258 -0.129823  0.930202 -0.312311
# 997  0.357722 -0.376163 -1.165783 -0.808817  0.182752  1.169759  0.540479
# 998 -1.979737  0.558306  0.840338  0.633681  0.286944 -0.507143 -0.880837
# 999  0.415795 -0.960206  1.487474  0.039711 -0.442399 -0.507143  0.256216
#
#        DfRlRt   DfDfClb       ST1       ST2       ST3       ST4     DfST1  \
# 0    1.891881  0.003907  0.174324  0.184352  0.184352  0.186407  0.089752
# 1   -0.169907  0.003907  0.174324  0.184352  0.184352  0.186407  0.089752
# 2   -0.246269  0.312346 -0.285028 -0.950820 -0.950820 -0.939239  3.498053
# 3    1.051893  0.106720 -0.055352  0.184352  0.184352  0.186407 -2.182449
# 4   -0.628082 -0.612972  0.633677  0.411386  0.411386  0.186407  1.225852
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.517356 -0.201719 -0.974057 -0.950820 -0.950820 -0.939239  0.089752
# 996 -0.169907  0.209533  0.633677  0.638421  0.638421  0.636665  0.089752
# 997 -0.169907  0.003907  0.863353  0.865455  0.865455  0.636665  0.089752
# 998 -0.169907  0.106720 -0.055352 -0.042682 -0.042682 -0.038722  0.089752
# 999 -0.398994 -0.818598 -0.055352 -0.042682 -0.042682 -0.038722  0.089752
#
#      DfST2     DfST3  DfST4        Sa
# 0      0.0  0.091926    0.0  0.186407
# 1      0.0  0.091926    0.0  0.186407
# 2      0.0  0.091926    0.0 -0.939239
# 3      0.0  0.091926    0.0  0.186407
# 4      0.0  1.763300    0.0  0.186407
# ..     ...       ...    ...       ...
# 995    0.0  0.091926    0.0 -0.939239
# 996    0.0 -1.579448    0.0  0.636665
# 997    0.0  0.091926    0.0  0.636665
# 998    0.0  0.091926    0.0 -0.038722
# 999    0.0  0.091926    0.0 -0.038722
#
# [1000 rows x 18 columns]

# %%
y_hats = lin_reg.predict(df_test_scaled)

df_test['prediction'] = y_hats

df_out = pd.merge(df_test, df_test[['prediction']], how = 'left', left_index = True, right_index = True)

# %%
result = df_out[['Id', 'prediction_x']]

# %%
result.rename({'prediction_x':'Target'}, inplace=True)
# Out:
# C:\Users\marci\anaconda3\envs\ML\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
result.iloc[:,0:]
# Out:
#         Id  prediction_x
# 0     7113      0.019922
# 1    15140      0.018580
# 2     3852      0.032699
# 3     1870      0.022134
# 4    12930      0.017925
# ..     ...           ...
# 995   6895      0.027577
# 996   8853      0.019469
# 997  11276      0.018285
# 998   3998      0.017381
# 999  12699      0.017679
#
# [1000 rows x 2 columns]

# %%
result.to_csv('Result.csv')
